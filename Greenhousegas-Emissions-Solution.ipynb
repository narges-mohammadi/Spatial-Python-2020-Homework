# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Task 1:

#Upload the csv-file "GreenhousegasEmissions.csv".

data = '/home/suny/EAGLE-Master/second-semester/spatial-python/SpatialPython2020/Exercises/GreenhousegasEmissions.csv'

greengas_df = pd.read_csv(data, sep=',')
#type(greengas_df)
#len(greengas_df)
#greengas_df.info()
greengas_df.tail()
greengas_df.head()
# Out:
#     unit airpol airemsect geo  time_2016  time_2015  time_2014  time_2013  \
# 0  MIO_T    CH4      CRF1  AT    0.02474    0.02467    0.02407    0.02668
# 1  MIO_T    CH4      CRF1  BE    0.04280    0.04253    0.03981    0.04395
# 2  MIO_T    CH4      CRF1  BG    0.05470    0.06022    0.05677    0.05707
# 3  MIO_T    CH4      CRF1  CH    0.01120    0.01113    0.01124    0.01229
# 4  MIO_T    CH4      CRF1  CY    0.00083    0.00080    0.00074    0.00075
#
#    time_2012  time_2011  ...  time_1994  time_1993  time_1992  time_1991  \
# 0    0.02627    0.02527  ...    0.03272    0.03952    0.04184    0.04265
# 1    0.04216    0.04210  ...    0.04682    0.05303    0.05177    0.05822
# 2    0.06402    0.06977  ...    0.09217    0.09972    0.09968    0.09146
# 3    0.01277    0.01335  ...    0.02554    0.02623    0.02657    0.02664
# 4    0.00083    0.00086  ...    0.00050    0.00047    0.00047    0.00045
#
#    time_1990  time_1989  time_1988  time_1987  time_1986  time_1985
# ...

# %%
# Task 2:

#Create an output, where all greenhouse gases of df are shown (column = airpol), 
#but only once (like an overview of all gases contained in df)

greengas_df.airpol.unique()

# Do the same for countries in df (column = geo)
greengas_df.geo.unique()
# Out:
# array(['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES',
#        'EU28', 'EU28_IS_K', 'FI', 'FR', 'HR', 'HU', 'IE', 'IS', 'IT',
#        'LI', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE',
#        'SI', 'SK', 'TR', 'UK'], dtype=object)

# %%
# Task 3:

# Choose one country of your choice (look at your output above) 
# and create a beautiful graph which shows the CH4, N2O, and CO2 emissions from 1994 to 2016.
#My choice for country: "NL"
emissions = ["CH4", "N2O", "CO2"]
Netherland_emission = greengas_df[(greengas_df['geo'] == 'NL') & (greengas_df['airpol'].isin(emissions))]
#Netherland_emission

Netherland_emission_yrange = Netherland_emission.iloc[:,1:27]
Netherland_emission_yrange
# Out:
# 23
#       airpol         airemsect geo  time_2016  time_2015  time_2014  \
# 25       CH4              CRF1  NL    0.08865    0.09288    0.09243
# 60       CH4     CRF1-6X4_MEMO  NL    0.74350    0.73742    0.72944
# 95       CH4  CRF1-6X4_MEMONIA  NL    0.74358    0.73750    0.72951
# 130      CH4       CRF1-6XMEMO  NL    0.74351    0.73744    0.72945
# 165      CH4             CRF1A  NL    0.06412    0.06690    0.06456
# ...      ...               ...  ..        ...        ...        ...
# 38149    N2O             CRF5E  NL    0.00000    0.00000    0.00000
# 38183    N2O              CRF6  NL    0.00000    0.00000    0.00000
# 38214    N2O        TOTX4_MEMO  NL   27.57000   28.42000   27.51000
# 38249    N2O     TOTX4_MEMONIA  NL   27.90000   28.74000   27.81000
# 38284    N2O          TOTXMEMO  NL   28.03000   28.86000   27.92000
#
#        time_2013  time_2012  time_2011  time_2010  ...  time_2003  time_2002  \
# ...
